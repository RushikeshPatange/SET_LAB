# %% [markdown]
# # Scatter Plot - Price V/s Age

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv('C:\\Users\\Admin\\Desktop\\sem_6\\SET_LAB\\ASS1\\Toyota.csv');

# %%
df.plot(kind  = 'scatter',x='Price',y='Age')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Age'>

# %% [markdown]
# # Histogram - Kilometer

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
toyota = pd.read_csv('C:\\Users\\Admin\\Desktop\\sem_6\\SET_LAB\\ASS1\\Toyota.csv');

# %% [markdown]
# # Histogram CC

# %%
toyota['CC'].plot(kind='hist');

# %%
toyota['KM'].fillna(toyota['KM'].median(),inplace=True)

# %% [markdown]
# # Histogram

# %%
toyota['KM'].plot(kind='hist');

# %%
import pandas as pd
import matplotlib.pyplot as plt

toyota = pd.read_csv('C:\\Users\\Admin\\Desktop\\sem_6\\SET_LAB\\ASS1\\Toyota.csv');
toyota = toyota.astype({'FuelType':str,'Price':str})
X = toyota['FuelType']
Y = toyota['Price']

# %%
plt.bar(X,Y,color='g')
plt.title("Bar Plot For Different Fuel Types")
plt.xlabel("FuelType")
plt.ylabel("Price")

plt.show()
